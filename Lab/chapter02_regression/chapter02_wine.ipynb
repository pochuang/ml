# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\pyml_scripts\chapter02_regression\winequality-red.csv',sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.matshow(df.corr())
plt.show()

# %%
import seaborn as sns
sns.pairplot(df.corr())
plt.show()

# %%
# c:\> pip install --upgrade seaborn --user
# 重新使用"Restart & Run All"
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), mask=np.zeros_like(df.corr(), dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True,annot=True)
plt.show()

# %% [markdown]
# 線性迴歸需要相關性強的特徵(不論正負)

# %%
plt.scatter(df['alcohol'], df['quality'])
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('Alcohol and Quality')
plt.show()

# %%
plt.scatter(df['volatile acidity'], df['quality'])
plt.xlabel('volatile acidity')
plt.ylabel('Quality')
plt.title('volatile acidity and Quality')
plt.show()

# %%
plt.scatter(df['density'], df['quality'])
plt.xlabel('density')
plt.ylabel('Quality')
plt.title('density and Quality')
plt.show()

# %%
plt.scatter(df['sulphates'], df['quality'])
plt.xlabel('sulphates')
plt.ylabel('Quality')
plt.title('sulphates and Quality')
plt.show()

# %%
plt.scatter(df['residual sugar'], df['quality'])
plt.xlabel('residual sugar')
plt.ylabel('Quality')
plt.title('residual sugar and Quality')
plt.show()

# %%
#一本正經地亂搞,此範例不適合使用regression,應該使用classification才對
from sklearn import linear_model
clf = linear_model.LinearRegression()
wine_noquality = df.drop("quality", axis=1)
X = wine_noquality.values 
Y = df['quality'].values
clf.fit(X, Y) 
clf.score(X, Y)
# Out:
# 0.36055170303868844

# %%
print(pd.DataFrame({"Name":wine_noquality.columns,"Coefficients":clf.coef_}).sort_values(by='Coefficients'))
# Out:
#                     Name  Coefficients
# 7                density    -17.881164
# 4              chlorides     -1.874225
# 1       volatile acidity     -1.083590
# 8                     pH     -0.413653
# 2            citric acid     -0.182564
# 6   total sulfur dioxide     -0.003265
# 5    free sulfur dioxide      0.004361
# 3         residual sugar      0.016331
# 0          fixed acidity      0.024991
# 10               alcohol      0.276198
# 9              sulphates      0.916334

# %%
print(clf.intercept_)
# Out:
# 21.965208449451914

# %%
wine_coef = pd.DataFrame({"Name":wine_noquality.columns,"Coefficients":clf.coef_})
wine_coef_group = wine_coef.groupby('Name')
wine_coef_sum = wine_coef_group.sum()
wine_plot = wine_coef_sum.plot(kind='bar')
ax = plt.axhline(y=0,color='black')
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import Normalizer
df = pd.read_csv(r'C:\pyml_scripts\chapter02_regression\winequality-red.csv',sep=';')
wine2_noquality = df.drop("quality", axis=1)
Y = df['quality'].values
wine2_normal = Normalizer().fit_transform(wine2_noquality)
X = wine2_normal
clf.fit(X, Y)
clf.score(X, Y)
# Out:
# 0.35980751054909754

# %% [markdown]
# ## 訓練誤差大到不能接受,因為label看似數值,其實是類別型態(ordinal)
# ## 所以應該使用分類演算法,而不是廻歸

# %%
print(pd.DataFrame({"Name":wine2_noquality.columns,"Coefficients":clf.coef_}).sort_values(by='Coefficients'))
# Out:
#                     Name  Coefficients
# 4              chlorides    -43.464794
# 7                density    -36.611490
# 1       volatile acidity    -35.112987
# 8                     pH    -19.775950
# 2            citric acid    -13.819478
# 3         residual sugar      0.517508
# 0          fixed acidity      1.581079
# 5    free sulfur dioxide      1.612678
# 6   total sulfur dioxide      2.346113
# 10               alcohol     10.565652
# 9              sulphates     40.458696

# %%
wine_coef = pd.DataFrame({"Name":wine2_noquality.columns,"Coefficients":clf.coef_})
wine_coef_group = wine_coef.groupby('Name')
wine_coef_sum = wine_coef_group.sum()
wine_plot = wine_coef_sum.plot(kind='bar')
ax = plt.axhline(y=0,color='black')
plt.show()

# %%
df = pd.read_csv(r'C:\pyml_scripts\chapter02_regression\winequality-red.csv',sep=';')

# %%
clf_ridge = linear_model.Ridge (alpha = .5)
wine_noquality = df.drop("quality", axis=1)
X = wine_noquality.values 
Y = df['quality'].values
clf_ridge.fit(X, Y) 
clf_ridge.score(X, Y)
# Out:
# 0.3600080990560508

# %%
clf_lasso = linear_model.Lasso(alpha = 0.01)
clf_lasso.fit(X, Y) 
clf_lasso.score(X, Y)
# Out:
# 0.33908790020160606

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
model = make_pipeline(PolynomialFeatures(4),Ridge())
model.fit(X, Y)
model.score(X, Y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.358866e-21
#   overwrite_a=True).T
# 0.7076425670585659

# %%
model = make_pipeline(PolynomialFeatures(4),Lasso())
model.fit(X, Y)
model.score(X, Y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0.43705262129066913

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (1439, 11) (160, 11)

# %%
model = make_pipeline(PolynomialFeatures(4),Ridge())
model.fit(X_train, Y_train)
print('訓練集正確性:{0:.3f},測試集正確性:{1:.3f}'.format(clf.score(X_train,Y_train),clf.score(X_test,Y_test)))
# Out:
# 訓練集正確性:-48911.822,測試集正確性:-47176.644
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:112: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.708569e-21
#   overwrite_a=True).T

# %%
clf = linear_model.LinearRegression()
clf.fit(X_train, Y_train) 
print('訓練集正確性:{0:.3f},測試集正確性:{1:.3f}'.format(clf.score(X_train,Y_train),clf.score(X_test,Y_test)))
# Out:
# 訓練集正確性:0.353,測試集正確性:0.431
